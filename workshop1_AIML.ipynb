# %%
from PIL import Image

# %%
image_colored=Image.open("/content/drive/MyDrive/AIML/lenna_image.png")

# %%
print("Format: ", image_colored.format)
print("Mode:", image_colored.mode)
print("Size:", image_colored.size)
# Out:
# Format:  PNG
# Mode: RGBA
# Size: (366, 357)

# %%
image_colored=image_colored.convert("RGB")
print(image_colored.mode)
# Out:
# RGB

# %% [markdown]
# Display only the top left corner of 100x100 pixels

# %%
top_left_corner = image_colored.crop((0, 0, 100, 100))
display(top_left_corner)
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100>

# %% [markdown]
# Modify the top 100 × 100 pixels to a value of 210 and display the resulting image

# %%
image_modified = np.array(image_colored)
image_modified[:100, :100] = 210  # Setting pixel values to 210
image_modified_pil = Image.fromarray(image_modified)
display(image_modified_pil)
# Out:
# <PIL.Image.Image image mode=RGBA size=366x357>

# %% [markdown]
# Grey Scale Image

# %%
image_grayed=image_colored.convert('L') #luminance change garni
display(image_grayed)
# Out:
# <PIL.Image.Image image mode=L size=366x357>

# %%
print("Format: ", image_grayed.format)
print("Mode:", image_grayed.mode)
print("Size:", image_grayed.size)
# Out:
# Format:  None
# Mode: L
# Size: (366, 357)

# %% [markdown]
#  Extract and display the middle section of the image (150 pixels)

# %%
mid_x, mid_y = width // 2, height // 2
cropped_mid_section = image_grayed.crop((mid_x - 75, mid_y - 75, mid_x + 75, mid_y + 75))
display(cropped_mid_section)
# Out:
# <PIL.Image.Image image mode=L size=150x150>

# %% [markdown]
# For Gray Scale Image:

# %%
width, height = image_grayed.size
channels=len(image_grayed.getbands())

print(f"Image shape (gray): ({height}, {width}, {channels})")

image_size_grayed=width*height*1
print(f"Image size (gray): {image_size_grayed}")
# Out:
# Image shape (gray): (357, 366, 1)
# Image size (gray): 130662

# %% [markdown]
# For Colored Image

# %%
width, height = image_colored.size
channels=len(image_colored.getbands())

print(f"Image shape (RGB): ({height}, {width}, {channels})")

image_size_colored=width*height*3
print(f"Image size (RGB): {image_size_colored}")
# Out:
# Image shape (RGB): (357, 366, 3)
# Image size (RGB): 391986

# %% [markdown]
# Converting to numpy

# %%
import numpy as np

# %%
image_array_colored = np.array(image_colored)
image_array_colored.shape
# Out:
# (357, 366, 4)

# %%
image_array_grayed = np.array(image_grayed)
image_array_grayed.shape
# Out:
# (357, 366)

# %% [markdown]
#  Apply a simple threshold to the image

# %%
threshold_value = 100
binary_image = image_array_grayed.copy()
binary_image[binary_image < threshold_value] = 0
binary_image[binary_image >= threshold_value] = 255
binary_image_pil = Image.fromarray(binary_image)
display(binary_image_pil)
# Out:
# <PIL.Image.Image image mode=L size=366x357>

# %% [markdown]
# Rotate the image 90 degrees clockwise and display the result

# %%
rotated_image = image_grayed.rotate(-90, expand=True)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=L size=357x366>

# %%
red_channel = image_array_colored[:,:,0]
print(red_channel)
display(red_channel)
# Out:
# [[225 224 226 ...  92  90  91]
#  [225 224 224 ...  91  90  91]
#  [223 223 224 ...  93  91  91]
#  ...
#  [ 88  92  95 ... 148 162 175]
#  [ 88  92  96 ... 154 168 177]
#  [254 254 254 ... 255 255 255]]
# array([[225, 224, 226, ...,  92,  90,  91],
#        [225, 224, 224, ...,  91,  90,  91],
#        [223, 223, 224, ...,  93,  91,  91],
#        ...,
#        [ 88,  92,  95, ..., 148, 162, 175],
#        [ 88,  92,  96, ..., 154, 168, 177],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8)

# %%
green_channel = image_array_colored[:,:,1]
print(green_channel)
display(green_channel)
# Out:
# [[127 130 130 ...  25  23  17]
#  [130 128 130 ...  22  22  20]
#  [128 133 129 ...  25  22  17]
#  ...
#  [ 23  22  26 ...  57  68  66]
#  [ 26  27  26 ...  63  71  66]
#  [254 254 254 ... 255 255 255]]
# array([[127, 130, 130, ...,  25,  23,  17],
#        [130, 128, 130, ...,  22,  22,  20],
#        [128, 133, 129, ...,  25,  22,  17],
#        ...,
#        [ 23,  22,  26, ...,  57,  68,  66],
#        [ 26,  27,  26, ...,  63,  71,  66],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8)

# %%
blue_channel = image_array_colored[:,:,2]
print(blue_channel)
display(blue_channel)
# Out:
# [[110 106 105 ...  64  62  56]
#  [110 104 114 ...  64  61  63]
#  [105 114 111 ...  67  65  61]
#  ...
#  [ 58  58  60 ...  78  84  78]
#  [ 58  61  61 ...  83  85  77]
#  [254 254 254 ... 255 255 255]]
# array([[110, 106, 105, ...,  64,  62,  56],
#        [110, 104, 114, ...,  64,  61,  63],
#        [105, 114, 111, ...,  67,  65,  61],
#        ...,
#        [ 58,  58,  60, ...,  78,  84,  78],
#        [ 58,  61,  61, ...,  83,  85,  77],
#        [254, 254, 254, ..., 255, 255, 255]], dtype=uint8)

# %%
red_channel = image_array_colored.copy()
red_channel[:,:,1]=0
red_channel[:,:,2]=0
print(red_channel)
display(red_channel)
# Out:
# [[[225   0   0]
#   [224   0   0]
#   [226   0   0]
#   ...
#   [ 92   0   0]
#   [ 90   0   0]
#   [ 91   0   0]]
#
#  [[225   0   0]
#   [224   0   0]
#   [224   0   0]
#   ...
#   [ 91   0   0]
#   [ 90   0   0]
#   [ 91   0   0]]
#
#  [[223   0   0]
#   [223   0   0]
#   [224   0   0]
#   ...
#   [ 93   0   0]
#   [ 91   0   0]
#   [ 91   0   0]]
#
#  ...
#
#  [[ 88   0   0]
#   [ 92   0   0]
#   [ 95   0   0]
#   ...
#   [148   0   0]
#   [162   0   0]
#   [175   0   0]]
#
#  [[ 88   0   0]
#   [ 92   0   0]
#   [ 96   0   0]
#   ...
#   [154   0   0]
#   [168   0   0]
#   [177   0   0]]
#
#  [[254   0   0]
#   [254   0   0]
#   [254   0   0]
#   ...
#   [255   0   0]
#   [255   0   0]
#   [255   0   0]]]
# array([[[225,   0,   0],
#         [224,   0,   0],
#         [226,   0,   0],
#         ...,
#         [ 92,   0,   0],
#         [ 90,   0,   0],
#         [ 91,   0,   0]],
#
#        [[225,   0,   0],
#         [224,   0,   0],
#         [224,   0,   0],
#         ...,
#         [ 91,   0,   0],
#         [ 90,   0,   0],
#         [ 91,   0,   0]],
#
#        [[223,   0,   0],
#         [223,   0,   0],
#         [224,   0,   0],
#         ...,
#         [ 93,   0,   0],
#         [ 91,   0,   0],
#         [ 91,   0,   0]],
#
#        ...,
#
#        [[ 88,   0,   0],
#         [ 92,   0,   0],
#         [ 95,   0,   0],
#         ...,
#         [148,   0,   0],
#         [162,   0,   0],
#         [175,   0,   0]],
#
#        [[ 88,   0,   0],
#         [ 92,   0,   0],
#         [ 96,   0,   0],
#         ...,
#         [154,   0,   0],
#         [168,   0,   0],
#         [177,   0,   0]],
#
#        [[254,   0,   0],
#         [254,   0,   0],
#         [254,   0,   0],
#         ...,
#         [255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0]]], dtype=uint8)

# %%
green_channel = image_array_colored.copy()
green_channel[:,:,0]=0
green_channel[:,:,2]=0
print(green_channel)
display(green_channel)
# Out:
# [[[  0 127   0]
#   [  0 130   0]
#   [  0 130   0]
#   ...
#   [  0  25   0]
#   [  0  23   0]
#   [  0  17   0]]
#
#  [[  0 130   0]
#   [  0 128   0]
#   [  0 130   0]
#   ...
#   [  0  22   0]
#   [  0  22   0]
#   [  0  20   0]]
#
#  [[  0 128   0]
#   [  0 133   0]
#   [  0 129   0]
#   ...
#   [  0  25   0]
#   [  0  22   0]
#   [  0  17   0]]
#
#  ...
#
#  [[  0  23   0]
#   [  0  22   0]
#   [  0  26   0]
#   ...
#   [  0  57   0]
#   [  0  68   0]
#   [  0  66   0]]
#
#  [[  0  26   0]
#   [  0  27   0]
#   [  0  26   0]
#   ...
#   [  0  63   0]
#   [  0  71   0]
#   [  0  66   0]]
#
#  [[  0 254   0]
#   [  0 254   0]
#   [  0 254   0]
#   ...
#   [  0 255   0]
#   [  0 255   0]
#   [  0 255   0]]]
# array([[[  0, 127,   0],
#         [  0, 130,   0],
#         [  0, 130,   0],
#         ...,
#         [  0,  25,   0],
#         [  0,  23,   0],
#         [  0,  17,   0]],
#
#        [[  0, 130,   0],
#         [  0, 128,   0],
#         [  0, 130,   0],
#         ...,
#         [  0,  22,   0],
#         [  0,  22,   0],
#         [  0,  20,   0]],
#
#        [[  0, 128,   0],
#         [  0, 133,   0],
#         [  0, 129,   0],
#         ...,
#         [  0,  25,   0],
#         [  0,  22,   0],
#         [  0,  17,   0]],
#
#        ...,
#
#        [[  0,  23,   0],
#         [  0,  22,   0],
#         [  0,  26,   0],
#         ...,
#         [  0,  57,   0],
#         [  0,  68,   0],
#         [  0,  66,   0]],
#
#        [[  0,  26,   0],
#         [  0,  27,   0],
#         [  0,  26,   0],
#         ...,
#         [  0,  63,   0],
#         [  0,  71,   0],
#         [  0,  66,   0]],
#
#        [[  0, 254,   0],
#         [  0, 254,   0],
#         [  0, 254,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]]], dtype=uint8)

# %%
blue_channel = image_array_colored.copy()
blue_channel[:,:,1]=0
blue_channel[:,:,0]=0
print(blue_channel)
display(blue_channel)
# Out:
# [[[  0   0 110]
#   [  0   0 106]
#   [  0   0 105]
#   ...
#   [  0   0  64]
#   [  0   0  62]
#   [  0   0  56]]
#
#  [[  0   0 110]
#   [  0   0 104]
#   [  0   0 114]
#   ...
#   [  0   0  64]
#   [  0   0  61]
#   [  0   0  63]]
#
#  [[  0   0 105]
#   [  0   0 114]
#   [  0   0 111]
#   ...
#   [  0   0  67]
#   [  0   0  65]
#   [  0   0  61]]
#
#  ...
#
#  [[  0   0  58]
#   [  0   0  58]
#   [  0   0  60]
#   ...
#   [  0   0  78]
#   [  0   0  84]
#   [  0   0  78]]
#
#  [[  0   0  58]
#   [  0   0  61]
#   [  0   0  61]
#   ...
#   [  0   0  83]
#   [  0   0  85]
#   [  0   0  77]]
#
#  [[  0   0 254]
#   [  0   0 254]
#   [  0   0 254]
#   ...
#   [  0   0 255]
#   [  0   0 255]
#   [  0   0 255]]]
# array([[[  0,   0, 110],
#         [  0,   0, 106],
#         [  0,   0, 105],
#         ...,
#         [  0,   0,  64],
#         [  0,   0,  62],
#         [  0,   0,  56]],
#
#        [[  0,   0, 110],
#         [  0,   0, 104],
#         [  0,   0, 114],
#         ...,
#         [  0,   0,  64],
#         [  0,   0,  61],
#         [  0,   0,  63]],
#
#        [[  0,   0, 105],
#         [  0,   0, 114],
#         [  0,   0, 111],
#         ...,
#         [  0,   0,  67],
#         [  0,   0,  65],
#         [  0,   0,  61]],
#
#        ...,
#
#        [[  0,   0,  58],
#         [  0,   0,  58],
#         [  0,   0,  60],
#         ...,
#         [  0,   0,  78],
#         [  0,   0,  84],
#         [  0,   0,  78]],
#
#        [[  0,   0,  58],
#         [  0,   0,  61],
#         [  0,   0,  61],
#         ...,
#         [  0,   0,  83],
#         [  0,   0,  85],
#         [  0,   0,  77]],
#
#        [[  0,   0, 254],
#         [  0,   0, 254],
#         [  0,   0, 254],
#         ...,
#         [  0,   0, 255],
#         [  0,   0, 255],
#         [  0,   0, 255]]], dtype=uint8)

# %%
r,g,b=image_colored.split()
display(r)
display(g)
display(b)
# Out:
# <PIL.Image.Image image mode=L size=366x357>
# <PIL.Image.Image image mode=L size=366x357>
# <PIL.Image.Image image mode=L size=366x357>

# %% [markdown]
# Extracting Sub Images deom an Image Array

# %%
row_100=image_array_colored[100,:,:]
print(row_100)
# Out:
# [[169  63  76]
#  [166  65  75]
#  [170  64  76]
#  ...
#  [210 132 122]
#  [209 133 116]
#  [208 134 126]]

# %%
left=100
upper=50
right=200
lower=150
cropped_image=image_colored.crop((left,upper,right,lower))
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %% [markdown]
# Saving NumPy Array to Image

# %%
image_array=np.zeros((100,100,3),dtype=np.uint8)
image_from_array=Image.fromarray(image_array)
image_from_array.show()
display(image_from_array)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
image_from_array.save("output_image.jpg")

# %% [markdown]
# # PCA

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image


image = Image.open("/content/drive/MyDrive/AIML/camera_man.jpg").convert("L")


image_array = np.array(image)
print(image_array.shape)



height, width = image_array.shape


#data = image_array.reshape( height , width )
data = image_array.copy()



plt.imshow(image_array, cmap='gray')
plt.show()
# Out:
# (325, 220)

# %%
# Compute the mean of each column ( feature )
mean = np.mean( data , axis =0)
# Subtract mean to center the data
centered_data = data - mean
centered_data = centered_data

# %%
centered_data.shape
# Out:
# (325, 220)

# %%
cov_matrix = np.cov(centered_data, rowvar=False)

# %%
cov_matrix.shape
# Out:
# (220, 220)

# %%
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]

# %%
explained_variance_ratio = eigenvalues / np .sum ( eigenvalues )
plt.plot ( np . cumsum ( explained_variance_ratio ) )
plt.title (" Cumulative Explained Variance ")
plt.xlabel (" Number of Components ")
plt.ylabel (" Cumulative Explained Variance ")
plt.grid ( True )
plt.show ()

# %%
k = 40 # Choose k principal components
components = eigenvectors [: , : k ]

# %%
compressed_data = np . dot ( centered_data , components )

# %%
decompressed_data = np . dot ( compressed_data , components . T ) + mean

# %%
plt . figure ( figsize =(12 , 6) )
# Original Image
plt.subplot (1 , 3 , 1)
plt.imshow ( image_array , cmap ="gray")
plt.title (" Original Image ")
plt.axis ("off")
# Compressed Representation
plt.subplot (1 , 3 , 2)
plt.imshow ( compressed_data , cmap ="gray", aspect ="auto")
plt.title ( f" Compressed Image (k={k})")
plt.axis ("off")
# Decompressed Image
plt.subplot (1 , 3 , 3)
plt.imshow ( decompressed_data , cmap ="gray")
plt.title (" Decompressed Image ")
plt.axis ("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# Pick Four k-values and compare

# %%
k_values = [10, 20, 40, 60]
plt.figure(figsize=(10, 5))

for i, k in enumerate(k_values, 1):
    components_k = eigenvectors[:, :k]
    compressed_k = np.dot(centered_data, components_k)
    decompressed_k = np.dot(compressed_k, components_k.T) + mean

    plt.subplot(1, 4, i)
    plt.imshow(decompressed_k, cmap='gray')
    plt.title(f'k={k}')
    plt.axis('off')

plt.show()
